# %% [markdown]
# # ArthLLM-2B — Kaggle Training Notebook
# Mounts GDrive, installs deps, resumes from latest checkpoint automatically.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -q bitsandbytes wandb tokenizers datasets
# !pip install -q flash-attn --no-build-isolation

# %%
import sys
sys.path.insert(0, '/kaggle/working/ArthLLM-2B')
from Training.master_train import train
train()
